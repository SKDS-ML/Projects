# %%
#import all the required libraries
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

# %% [markdown]
# # Q1: Write a python program to scrape data for “Data Analyst” Job position in
# “Bangalore” location. You have to scrape the job-title, job-location, company_name,
# experience_required. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Analyst” in “Skill,Designations,Companies” field and enter “Bangalore”
# in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)
url = "https://www.naukri.com/"
driver.get(url)
time.sleep(6)
search_field_designation=driver.find_element_by_id("qsb-keyword-sugg")
search_field_location=driver.find_element_by_id('qsb-location-sugg')
search_field_designation.send_keys("Data Analyst")
search_field_location.send_keys("Bangalore")
search_button=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()
time.sleep(4)
job_title=[]
job_location=[]
company_name=[]
experience_required=[]
titles=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in titles:
    if i.text is None :
        job_title.append("--") 
    else:
        job_title.append(i.text)
time.sleep(4)
locations=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    if i.text is None :
        job_location.append("--") 
    else:
        job_location.append(i.text)
time.sleep(4)         
companies=driver.find_elements_by_xpath("//div[@class='mt-7 companyInfo subheading lh16']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)
company_name[0:2]
time.sleep(4) 
experience=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span[1]")
for i in experience:
    if i.text is None :
            experience_required.append("--") 
    else:
            experience_required.append(i.text)
time.sleep(4)
df=pd.DataFrame({"experience_required":experience_required[0:10],"company_name":company_name[0:10],"job_location":job_location[0:10],
                "job_title":job_title[0:10]})
df
# Out:
#   experience_required                       company_name  \
# 0             1-5 Yrs        AN INFRACON PRIVATE LIMITED
# 1             2-5 Yrs  Flipkart Internet Private Limited
# 2             1-5 Yrs                     (3334 Reviews)
# 3             3-6 Yrs             RANDSTAD INDIA PVT LTD
# 4            7-10 Yrs                     (1127 Reviews)
# 5             3-5 Yrs              Philips India Limited
# 6             3-6 Yrs                      (539 Reviews)
# 7             4-9 Yrs                  Applied Materials
# 8             5-8 Yrs                       (96 Reviews)
# 9             2-3 Yrs                  Microland Limited
#
#                                job_location  \
# 0  Chennai, Coimbatore, Bangalore/Bengaluru
# 1                       Bangalore/Bengaluru
# 2         Bangalore/Bengaluru(Marathahalli)
# 3                       Bangalore/Bengaluru
# 4                       Bangalore/Bengaluru
# 5                       Bangalore/Bengaluru
# 6                       Bangalore/Bengaluru
# 7                       Bangalore/Bengaluru
# 8   Bangalore/Bengaluru(2nd Phase JP Nagar)
# 9                       Bangalore/Bengaluru
#
#                                            job_title
# 0  Business Analyst / Data Analyst - SQL Queries,...
# 1                                Senior Data Analyst
# 2  Immediate job openings For Partner Consultant ...
# 3                                       Data Analyst
# 4                                       Data Analyst
# 5                                Senior Data Analyst
# 6                                Senior Data Analyst
# 7  Hiring- SR Data Analyst /Bangalore Start Up Co...
# 8                                Senior Data Analyst
# 9                Data Analyst, Component Engineering

# %% [markdown]
# # Q2: Write a python program to scrape data for “Data Scientist” Job position in
# “Bangalore” location. You have to scrape the job-title, job-location,
# company_name, full job-description. You have to scrape first 10 jobs data.
# This task will be done in following steps:
# 1. first get the webpage https://www.naukri.com/
# 2. Enter “Data Scientist” in “Skill,Designations,Companies” field and enter
# “Bangalore” in “enter the location” field.
# 3. Then click the search button.
# 4. Then scrape the data for the first 10 jobs results you get.
# 5. Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)
url = "https://www.naukri.com/"
driver.get(url)
time.sleep(6)
search_field_designation=driver.find_element_by_id("qsb-keyword-sugg")
search_field_location=driver.find_element_by_id('qsb-location-sugg')
search_field_designation.send_keys("Data Scientist")
search_field_location.send_keys("Bangalore")
search_button=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()
time.sleep(4)
job_title=[]
job_location=[]
company_name=[]
full_job_description=[]
titles=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in titles:
    if i.text is None :
        job_title.append("--") 
    else:
        job_title.append(i.text)
time.sleep(4)
locations=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    if i.text is None :
        job_location.append("--") 
    else:
        job_location.append(i.text)      
time.sleep(4)         
companies=driver.find_elements_by_xpath("//div[@class='mt-7 companyInfo subheading lh16']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)
urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")]
for url in urls[0:10]:
    try:    
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//section[@class='job-desc']/div[1]").text
        description=raw_description.replace("Contact Person","@@@@@")
        description= description.split("@@@@@")
        full_job_description.append(description[0])
    except NoSuchElementException :
        full_job_description.append("---")
df=pd.DataFrame({"job_title":job_title[0:10],"company_name":company_name[0:10],"job_location":job_location[0:10],
                "job_description":full_job_description[0:10]})
df
# Out:
#                                            job_title           company_name  \
# 0                            Senior Data Scientist I  Philips India Limited
# 1                          IDM - Lead Data Scientist          (539 Reviews)
# 2                           Principal Data Scientist  Philips India Limited
# 3                Data Scientist - Business Analytics          (539 Reviews)
# 4                                     Data Scientist  Philips India Limited
# 5                                     Data Scientist          (539 Reviews)
# 6                                     Data Scientist  Philips India Limited
# 7                                     Data Scientist          (539 Reviews)
# 8  Immediately hiring For Data Scientist - (Banga...  Philips India Limited
# 9  Immediately hiring For Data Scientist - (Banga...          (539 Reviews)
#
#                                         job_location  \
# 0                                Bangalore/Bengaluru
# 1                                Bangalore/Bengaluru
# 2                                Bangalore/Bengaluru
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 6  Kolkata, Hyderabad/Secunderabad, Pune, Ahmedab...
# 7                                Bangalore/Bengaluru
# 8                                Bangalore/Bengaluru
# 9                                Bangalore/Bengaluru
#
#                                      job_description
# 0  Job Responsibilities\nUse predictive modeling ...
# 1  Your responsibilities\nEnsure strategic direct...
# 2  In this role, you have the opportunity to\nPro...
# 3  Support business in their decision making need...
# 4  In this role, you have the opportunity to\nPro...
# 5  Brief JD\nExperience: 5 - 10 Yrs\n\n\nSkills a...
# 6  Brief JD\nExperience: 5 - 10 Yrs\n\n\nSkills a...
# 7                                                ---
# 8  Preferred Qualifications\n5-8 years experience...
# 9  Preferred Qualifications\n5-8 years experience...

# %% [markdown]
# # Q3: In this question you have to scrape data using the filters available on the webpage as shown below: You have to use the location and salary filter. You have to scrape data for “Data Scientist” designation for first 10 job results. You have to scrape the job-title, job-location, company_name, experience_required. The location filter to be used is “Delhi/NCR” The salary filter to be used is “3-6” lakhs The task will be done as shown in the below steps:
# first get the webpage https://www.naukri.com/
# Enter “Data Scientist” in “Skill,Designations,Companies” field .
# Then click the search button.
# Then apply the location filter and salary filter by checking the respective boxes
# Then scrape the data for the first 10 jobs results you get.
# Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)
url = "https://www.naukri.com/"
driver.get(url)
time.sleep(6)
search_field_designation=driver.find_element_by_id("qsb-keyword-sugg")
search_field_designation.send_keys("Data Scientist")
search_button=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()
job_title=[]
job_location=[]
company_name=[]
experience_required=[]
time.sleep(3)
loc=driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[2]/div[2]/div[2]/label/p")
loc.click()
time.sleep(2)
slry_box = driver.find_element_by_xpath("/html/body/div[1]/div[3]/div[2]/section[1]/div[2]/div[3]/div[2]/div[2]/label/p")
slry_box.click()
time.sleep(3)
titles=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in titles:
    if i.text is None :
        job_title.append("--") 
    else:
        job_title.append(i.text)     
time.sleep(3)
locations=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    if i.text is None :
        job_location.append("--") 
    else:
        job_location.append(i.text) 
time.sleep(3) 
companies=driver.find_elements_by_xpath("//div[@class='mt-7 companyInfo subheading lh16']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)      
time.sleep(3)
experience=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span[1]")
for i in experience:
    if i.text is None :
            experience_required.append("--") 
    else:
            experience_required.append(i.text)           
time.sleep(3)            
df=pd.DataFrame({"job_title":job_title[0:10],"experience_required":experience_required[0:10],"company_name":company_name[0:10],
                 "job_location":job_location[0:10]})
df
# Out:
#                                            job_title experience_required  \
# 0    Data Scientist / Data Analyst -Business Analyst             0-3 Yrs
# 1  Only Fresher / Data Scientist / Data Analyst /...             0-0 Yrs
# 2  Data analytics / Data scientist intern (work f...             0-5 Yrs
# 3                  Data Scientist - Text NLP | Noida             3-5 Yrs
# 4              Data Scientist - Machine Learning/NLP             2-6 Yrs
# 5                                     Data Scientist             3-7 Yrs
# 6                                     Data Scientist             3-8 Yrs
# 7              Data Scientist - Machine Learning/NLP             2-4 Yrs
# 8                                     Data Scientist             3-7 Yrs
# 9                                     Data Scientist             1-3 Yrs
#
#                             company_name  \
# 0     Inflexion Analytix Private Limited
# 1              GABA Consultancy services
# 2                         TalkValley LLC
# 3                            (2 Reviews)
# 4            Acidaes Solutions Pvt. Ltd.
# 5                           (66 Reviews)
# 6                                 TalPro
# 7                      Fractal Analytics
# 8                           (96 Reviews)
# 9  NEC CORPORATION INDIA PRIVATE LIMITED
#
#                                         job_location
# 0  Mumbai, Hyderabad/Secunderabad, Pune, Gurgaon/...
# 1               Noida, Gurgaon/Gurugram, Delhi / NCR
# 2          Kolkata, Bangalore/Bengaluru, Delhi / NCR
# 3                                              Noida
# 4                                   Gurgaon/Gurugram
# 5      Mumbai, Gurgaon/Gurugram, Bangalore/Bengaluru
# 6                                              Noida
# 7                                   Gurgaon/Gurugram
# 8              Gurgaon/Gurugram, Bangalore/Bengaluru
# 9  Bharuch, Jaipur, Bhopal, Mumbai, Jhansi, Nagpu...

# %% [markdown]
# # Q4: Write a python program to scrape data for first 10 job results for Data scientist Designation in Noida location. You have to scrape company_name, No. of days ago when job was posted, Rating of the company. This task will be done in following steps:
# first get the webpage https://www.glassdoor.co.in/index.htm
# Enter “Data Scientist” in “Job Title,Keyword,Company” field and enter “Noida” in “location” field.
# Then click the search button. You will land up in the below page:
# Then scrape the data for the first 10 jobs results you get in the above shown page. WEB SCRAPING ASSIGNMENT-2 .
# Finally create a dataframe of the scraped data.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)
url = "https://www.glassdoor.co.in/index.htm"
driver.get(url)
search_field_designation=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input")  #job search bar
search_field_designation.send_keys("Data Scientist")
time.sleep(2)
search_field_location=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[3]//div[1]//input")  #location search bar
search_field_location.clear()
search_field_location.send_keys("Noida")
time.sleep(2)
search_button=driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
search_button.click()
company_ratings=[]
company_name=[]
days_ago=[]
time.sleep(3)
companies=driver.find_elements_by_xpath("//div[@class='d-flex justify-content-between align-items-start']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)    
time.sleep(3)        
ratings=driver.find_elements_by_xpath("//span[@class='css-19pjha7 e1cjmv6j1']")
for i in ratings:
    if i.text is None :
        company_ratings.append("--") 
    else:
        company_ratings.append(i.text)
time.sleep(3)
days=driver.find_elements_by_xpath("//div[@class='d-flex align-items-end pl-std css-mi55ob']")
for i in days:
    if i.text is None :
        days_ago.append("--") 
    else:
        days_ago.append(i.text)         
time.sleep(3)        
df=pd.DataFrame({"company_name":company_name[0:10],"company_ratings":company_ratings[0:10],"days_ago":days_ago[0:10]})
df
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-10-f95088bdd2c6> in <module>
# ----> 1 search_field_designation=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input")  #job search bar
#       2 search_field_designation.send_keys("Data Scientist")
#       3 time.sleep(2)
#       4 search_field_location=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[3]//div[1]//input")  #location search bar
#       5 search_field_location.clear()
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input"}
#   (Session info: chrome=91.0.4472.114)

# %% [markdown]
# # Q5: Write a python program to scrape the salary data for Data Scientist designation in Noida location. You have to scrape Company name, Number of salaries, Average salary, Min salary, Max Salary. The above task will be, done as shown in the below steps:
# first get the webpage https://www.glassdoor.co.in/Salaries/index.htm
# Enter “Data Scientist” in Job title field and “Noida” in location field.
# Click the search button.
# After that you will land on the below page You have to scrape whole data from this webpage
# Scrape data for first 10 companies. Scrape the min salary, max salary, company name, Average salary and rating of the company. 6.Store the data in a dataframe

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)
url = "https://www.glassdoor.co.in/index.htm"
driver.get(url)
search_field_designation=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input")
search_field_designation.send_keys("Data Scientist")
time.sleep(2)
from selenium.webdriver.common.keys import Keys
for i in range(9):
    driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[3]//div[1]//input").send_keys(Keys.BACK_SPACE)
search_field_location=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[3]//div[1]//input")  
search_field_location.send_keys("Noida")
time.sleep(2)
option = driver.find_element_by_xpath("//div[@class='selectedLabel']")
option.click()
time.sleep(2)
salary_option = driver.find_element_by_xpath("//div[@class='dropDownOptionsContainer']//ul//li[3]")
salary_option.click()
time.sleep(2)
search_button=driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
search_button.click()
company_name=[]
min_salaries=[]
max_salaries=[]
average_salaries=[]
no_of_salaries=[]
time.sleep(3)
company=driver.find_elements_by_xpath("//div[@data-test='job-info']/p[2]")
for i in company:
    if i.text is None :
        company_name.append("--")      
    else:
        company_name.append(i.text)    
time.sleep(3)        
min_salary = driver.find_elements_by_xpath("//div[@class='common__RangeBarStyle__values d-flex justify-content-between ']//span[1]")
for i in min_salary:
    if i.text is None:
        min_salaries.append("--")
    else:
        min_salaries.append(i.text)
time.sleep(3)        
max_salary=driver.find_elements_by_xpath("//div[@class='common__RangeBarStyle__values d-flex justify-content-between ']/span[2]")
for i in max_salary:
    if i.text is None :
        max_salaries.append("--") 
    else:
        max_salaries.append(i.text)  
time.sleep(3)        
average_salary=driver.find_elements_by_xpath("//div[@class='col-2 d-none d-md-flex flex-row justify-content-end']/strong")
for i in average_salary:
    if i.text is None :
        average_salaries.append("--") 
    else:
        average_salaries.append(i.text)    
time.sleep(3)        
no_of_salary=driver.find_elements_by_xpath("//p[@class='css-1uyte9r css-1kuy7z7 m-0 ']")
for i in no_of_salary:
    if i.text is None :
        no_of_salaries.append("--") 
    else:
        no_of_salaries.append(i.text) 
df=pd.DataFrame({"company_name":company_name,"min_salaries":min_salaries,"max_salaries":max_salaries,
                 "average_salaries":average_salaries,"no_of_salaries":no_of_salaries})
df
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-12-3f53a103c964> in <module>
# ----> 1 search_field_designation=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input")
#       2 search_field_designation.send_keys("Data Scientist")
#       3 time.sleep(2)
#       4 from selenium.webdriver.common.keys import Keys
#       5 for i in range(9):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     392             element = driver.find_element_by_xpath('//div/td[1]')
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#     396     def find_elements_by_xpath(self, xpath):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input"}
#   (Session info: chrome=91.0.4472.114)

# %% [markdown]
# # Q6 : Scrape data of first 100 sunglasses listings on flipkart.com. You have to scrape four attributes:
# Brand
# Product Description
# Price
# Discount To scrape the data you have to go through following steps:
# Go to flipkart webpage by url https://www.flipkart.com/
# Enter “sunglasses” in the search field where “search for products, brands and more” is written and click the search icon
# after that you will reach to a webpage having a lot of sunglasses. From this page you can scrap the required data as usual.
# after scraping data from the first page, go to the “Next” Button at the bottom of the page , then click on it

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)
url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(2)
search_bar=driver.find_element_by_class_name("_3704LK")
search_bar.send_keys('sunglasses')
time.sleep(2)
button=driver.find_element_by_class_name('L0Z3Pu')
button.click()
brand=[]
description=[]
price=[]
discount=[]
time.sleep(3)
start=0
end=4
for page in range(start,end):
    brands=driver.find_elements_by_class_name('_2WkVRV')
    for i in brands:
        brand.append(i.text)
    desc=driver.find_elements_by_xpath('//a[@class="IRpwTa"]')
    for i in desc:
        description.append(i.text)
    prices=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
    for i in prices:
        price.append(i.text)
    disc=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']//span")
    for i in disc:
        discount.append(i.text)
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))
time.sleep(3)        
df=pd.DataFrame({'Brand':brand[:100],
                'Description':description[:100],
                'Price':price[:100],
                'Discount':discount[:100]})
df
# Out:
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# <ipython-input-15-6b8918faa200> in <module>
#       8 time.sleep(2)
#       9 button=driver.find_element_by_class_name('L0Z3Pu')
# ---> 10 button.click()
#      11 brand=[]
#      12 description=[]
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in click(self)
#      78     def click(self):
#      79         """Clicks the element."""
# ---> 80         self._execute(Command.CLICK_ELEMENT)
#      81
#      82     def submit(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in _execute(self, command, params)
#     631             params = {}
#     632         params['id'] = self._id
# --> 633         return self._parent.execute(command, params)
#     634
#     635     def find_element(self, by=By.ID, value=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button class="L0Z3Pu" type="submit">...</button> is not clickable at point (556, 28). Other element would receive the click: <div class="_2hriZF _2rbIyg" tabindex="-1">...</div>
#   (Session info: chrome=91.0.4472.114)

# %% [markdown]
# # Q7: Scrape 100 reviews data from flipkart.com for iphone11 phone. You have to go the link: https://www.flipkart.com/apple-iphone-11-black-64-gb-includesearpods-poweradapter/p/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace. you have to scrape the below mention attributes. These are
# Rating
# Review_summary
# Full review You have to scrape this data for first 100 reviews

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)
url = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART"
driver.get(url)
time.sleep(2)
urls=[]
short_review=[]
complete_review=[]
stars=[]
time.sleep(4)
for i in range(10):
    url=driver.find_element_by_xpath("//a[@class='ge-49M']").get_attribute('href')
    driver.get(url)
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
        stars.append(j.text)
    for k in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        short_review.append(k.text)
    for l in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        complete_review.append(l.text)
df=pd.DataFrame({'Number of Stars': stars,
                'Short Review': short_review,
               'Full Review': complete_review})
df
# Out:
#    Number of Stars        Short Review  \
# 0                5    Perfect product!
# 1                5  Highly recommended
# 2                5   Worth every penny
# 3                5    Perfect product!
# 4                5      Simply awesome
# 5                5  Highly recommended
# 6                5   Worth every penny
# 7                5            Terrific
# 8                5    Perfect product!
# 9                4        Nice product
# 10               5           Brilliant
# 11               5    Perfect product!
# 12               5           Fabulous!
# 13               5   Worth every penny
# 14               5       Great product
# 15               5   Worth every penny
# 16               4         Good choice
# 17               5      Simply awesome
# 18               5  Highly recommended
# 19               5    Perfect product!
# 20               5    Perfect product!
# 21               5  Highly recommended
# 22               5   Worth every penny
# 23               5    Perfect product!
# 24               5      Simply awesome
# 25               5  Highly recommended
# 26               5   Worth every penny
# 27               5            Terrific
# 28               5    Perfect product!
# 29               4        Nice product
# ..             ...                 ...
# 70               5           Brilliant
# 71               5    Perfect product!
# 72               5           Fabulous!
# 73               5   Worth every penny
# 74               5       Great product
# 75               5   Worth every penny
# 76               4         Good choice
# 77               5      Simply awesome
# 78               5  Highly recommended
# 79               5    Perfect product!
# 80               5    Perfect product!
# 81               5  Highly recommended
# 82               5   Worth every penny
# 83               5    Perfect product!
# 84               5      Simply awesome
# 85               5  Highly recommended
# 86               5   Worth every penny
# 87               5            Terrific
# 88               5    Perfect product!
# 89               4        Nice product
# 90               5           Brilliant
# 91               5    Perfect product!
# 92               5           Fabulous!
# 93               5   Worth every penny
# 94               5       Great product
# 95               5   Worth every penny
# 96               4         Good choice
# 97               5      Simply awesome
# 98               5  Highly recommended
# 99               5    Perfect product!
#
#                                           Full Review
# 0   Value for money❤️❤️\nIts awesome mobile phone ...
# 1   What a camera .....just awesome ..you can feel...
# 2   Best budget Iphone till date ❤️ go for it guys...
# 3   Iphone is just awesome.. battery backup is ver...
# 4   Excellent camera, good performance, no lag. Th...
# 5   It's my first time to use iOS phone and I am l...
# 6   It’s been almost a month since I have been usi...
# 7   Really worth of money. i just love it. It is t...
# 8   Battery backup is extraordinary, camera is dec...
# 9   Awesome Phone. Slightly high price but worth. ...
# 10  The Best Phone for the Money\n\nThe iPhone 11 ...
# 11  Amazing phone with great cameras and better ba...
# 12  This is my first iOS phone. I am very happy wi...
# 13  Previously I was using one plus 3t it was a gr...
# 14  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 15  i11 is worthy to buy, too much happy with the ...
# 16  So far it’s been an AMAZING experience coming ...
# 17  Really satisfied with the Product I received.....
# 18  iphone 11 is a very good phone to buy only if ...
# 19  It’s a must buy who is looking for an upgrade ...
# 20  Value for money❤️❤️\nIts awesome mobile phone ...
# 21  What a camera .....just awesome ..you can feel...
# 22  Best budget Iphone till date ❤️ go for it guys...
# 23  Iphone is just awesome.. battery backup is ver...
# 24  Excellent camera, good performance, no lag. Th...
# 25  It's my first time to use iOS phone and I am l...
# 26  It’s been almost a month since I have been usi...
# 27  Really worth of money. i just love it. It is t...
# 28  Battery backup is extraordinary, camera is dec...
# 29  Awesome Phone. Slightly high price but worth. ...
# ..                                                ...
# 70  The Best Phone for the Money\n\nThe iPhone 11 ...
# 71  Amazing phone with great cameras and better ba...
# 72  This is my first iOS phone. I am very happy wi...
# 73  Previously I was using one plus 3t it was a gr...
# 74  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 75  i11 is worthy to buy, too much happy with the ...
# 76  So far it’s been an AMAZING experience coming ...
# 77  Really satisfied with the Product I received.....
# 78  iphone 11 is a very good phone to buy only if ...
# 79  It’s a must buy who is looking for an upgrade ...
# 80  Value for money❤️❤️\nIts awesome mobile phone ...
# 81  What a camera .....just awesome ..you can feel...
# 82  Best budget Iphone till date ❤️ go for it guys...
# 83  Iphone is just awesome.. battery backup is ver...
# 84  Excellent camera, good performance, no lag. Th...
# 85  It's my first time to use iOS phone and I am l...
# 86  It’s been almost a month since I have been usi...
# 87  Really worth of money. i just love it. It is t...
# 88  Battery backup is extraordinary, camera is dec...
# 89  Awesome Phone. Slightly high price but worth. ...
# 90  The Best Phone for the Money\n\nThe iPhone 11 ...
# 91  Amazing phone with great cameras and better ba...
# 92  This is my first iOS phone. I am very happy wi...
# 93  Previously I was using one plus 3t it was a gr...
# 94  Amazing Powerful and Durable Gadget.\n\nI’m am...
# 95  i11 is worthy to buy, too much happy with the ...
# 96  So far it’s been an AMAZING experience coming ...
# 97  Really satisfied with the Product I received.....
# 98  iphone 11 is a very good phone to buy only if ...
# 99  It’s a must buy who is looking for an upgrade ...
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q8:Scrape data for first 100 sneakers you find when you visit flipkart.comand search for “sneakers” in the search field.You have to scrape 4 attributes of each sneaker :
# Brand
# Product Description
# Price
# discount % Also note that all the steps required during scraping should be done through code only and not manually.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)
url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(2)
log_in_pop_up = driver.find_element_by_xpath("//button[@class='_2KpZ6l _2doB4z']")
log_in_pop_up.click()
time.sleep(2)
search_bar=driver.find_element_by_class_name("_3704LK")
search_bar.clear()
search_bar.send_keys('sneakers')
time.sleep(2)
button=driver.find_element_by_class_name('L0Z3Pu')
button.click()
brand=[]
description=[]
price=[]
discount=[]
time.sleep(3)
start=0
end=4
for page in range(start,end):
    brands=driver.find_elements_by_class_name('_2WkVRV')
    for i in brands:
        brand.append(i.text)
    prices=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
    for i in prices:
        price.append(i.text)
    disc=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']//span")
    for i in disc:
        discount.append(i.text)
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))                
time.sleep(2)        
urls = []
for page in range(0,4):
    product_url = driver.find_elements_by_xpath("//a[@class='_2UzuFa']")
    for i in product_url:
        urls.append(i.get_attribute('href'))
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))
time.sleep(2)        
for i in urls:
    driver.get(i)
    desc=driver.find_elements_by_xpath('//span[@class="B_NuCI"]')
    for i in desc:
        description.append(i.text)
time.sleep(2)        
time.sleep(3)        
df=pd.DataFrame({'Brand':brand[:100],
                'Description':description[:100],
                'Price':price[:100],
                'Discount':discount[:100]})
df
# Out:
#                   Brand                                        Description  \
# 0                ADIDAS  Skypy-31 Walking Shoes,Training Shoes,Sneakers...
# 1                  PUMA  Casual , Partywear Sneakers Shoes For Men's An...
# 2                Alfiya         Court Vision Low Sneakers For Men  (Black)
# 3              CALCADOS           LEBRON 2.0 Sneakers For Men  (Off White)
# 4          Robbie jones  Perfect & Affordable Combo Pack of 02 Pairs Sn...
# 5            Shoes Bank       Dexster Slip On IDP Sneakers For Men  (Blue)
# 6                Chevit              Anzarun Lite Sneakers For Men  (Blue)
# 7       U.S. POLO ASSN.                   Sneakers For Men  (White, Black)
# 8          Stefano Rads   SB Heritage Vulc Skate Sneakers For Men  (White)
# 9                  KULP  Casual Sneakers Shoes For Men Sneakers For Men...
# 10             PEHANOSA       Court Royale 2 Low Sneakers For Men  (Black)
# 11                Clymb  Unique & Perfect Collection Combo Pack of 02 S...
# 12         Robbie jones  Synthetic Leather Casual Sneakers Shoes For Me...
# 13               Chevit                          Sneakers For Men  (Beige)
# 14            bluemaker                       R78 Sneakers For Men  (Grey)
# 15             RED TAPE       Puma Smash v2 Buck Sneakers For Men  (Black)
# 16               Kraasa    Flex Generation V1 IDP Sneakers For Men  (Grey)
# 17  World Wear Footwear           ST Runner v2 NL Sneakers For Men  (Blue)
# 18          kardam&sons                          Sneakers For Men  (Black)
# 19                 PUMA                 Breaknet Sneakers For Men  (White)
# 20            India hub            INDI EXCLUSIVE Sneaker For Men  (Black)
# 21         Robbie jones                           Sneakers For Men  (Navy)
# 22              Nilatin               Baymax IDP Sneakers For Men  (White)
# 23             RED TAPE                       Sneakers For Men  (Burgundy)
# 24  World Wear Footwear                Respin SL Sneakers For Men  (Black)
# 25           D-SNEAKERZ                           Sneakers For Men  (Grey)
# 26              Numenzo              Escaper Pro Sneakers For Men  (Black)
# 27             RED TAPE  Speed Set of 5 Pairs Sneakers Outdoors Casuals...
# 28            SCATCHITE                          Sneakers For Men  (White)
# 29             HOTSTYLE                          Sneakers For Men  (Brown)
# ..                  ...                                                ...
# 70              ESSENCE           Indi Exclusive Sneakers For Men  (White)
# 71               BRUTON  Speed Set of 5 Pairs Sneakers Outdoors Casuals...
# 72              ESSENCE    Backcourt Mid Rainbow Sneakers For Men  (White)
# 73               CAMPUS                  Cape IDP Sneakers For Men  (Grey)
# 74             HOCKWOOD                     EMAN Sneakers For Men  (Black)
# 75               BRUTON        Puma Smash v2 Buck Sneakers For Men  (Blue)
# 76          kardam&sons                          Sneakers For Men  (White)
# 77              Jokatoo  Karda Casual Sneakers and Gym Shoes for Men's ...
# 78         Robbie jones                   SM-439 Sneakers For Men  (White)
# 79             RED TAPE                 HHM Sneakers For Men  (Multicolor)
# 80              Imcolus                     Sneakers For Men  (Multicolor)
# 81              tigonis          Puma Smash v2 L Sneakers For Men  (White)
# 82               Chevit      Men SM-461 Navy Blue Sneakers For Men  (Blue)
# 83      U.S. POLO ASSN.           LEBRON 2.0 Sneakers For Men  (Off White)
# 84               BRUTON             Easy Vulc 2.0 Sneakers For Men  (Grey)
# 85  World Wear Footwear                Men Boxer Sneakers For Men  (Black)
# 86                 PUMA                           Sneakers For Men  (Grey)
# 87    STRANGER BROTHERS                   Sneakers For Men  (White, Black)
# 88                SPARX  NewSneakers,Outdoors,Dancing,Casuals, Partywea...
# 89                 FILA                  STYLISH Sneakers For Men  (White)
# 90         Jack Diamond  Nike Court Royale 2 Low Men's Shoe Sneakers Fo...
# 91               Chevit  Unique & Perfect Collection Combo Pack of 02 S...
# 92               BRUTON                   STYLISH Sneakers For Men  (Blue)
# 93               BRUTON                     Sneakers For Men  (Multicolor)
# 94     Absolute comfort                          Sneakers For Men  (Black)
# 95                 PUMA       Puma Smash v2 Buck Sneakers For Men  (Black)
# 96            Englewood                          Sneakers For Men  (White)
# 97                Zsyto          Court Royale AC Sneakers For Men  (White)
# 98                 PUMA                           Sneakers For Men  (Navy)
# 99                Clymb                 Breaknet Sneakers For Men  (White)
#
#      Price   Discount
# 0   ₹1,978  ₹2621 off
# 1   ₹1,375  ₹2124 off
# 2     ₹377   ₹622 off
# 3     ₹748  ₹1248 off
# 4     ₹379   ₹620 off
# 5     ₹318   ₹681 off
# 6     ₹495  ₹1003 off
# 7   ₹3,999   ₹470 off
# 8     ₹229   ₹580 off
# 9     ₹419   ₹500 off
# 10    ₹499   ₹721 off
# 11    ₹278   ₹600 off
# 12    ₹399  ₹1736 off
# 13    ₹759   ₹550 off
# 14    ₹449  ₹2867 off
# 15  ₹1,228   ₹583 off
# 16    ₹416   ₹259 off
# 17    ₹240  ₹1620 off
# 18    ₹379  ₹1749 off
# 19  ₹1,750  ₹2630 off
# 20    ₹369   ₹550 off
# 21    ₹449   ₹892 off
# 22    ₹407  ₹3075 off
# 23  ₹1,024  ₹2141 off
# 24    ₹499   ₹294 off
# 25    ₹365   ₹601 off
# 26    ₹398  ₹3917 off
# 27  ₹1,678   ₹622 off
# 28    ₹377   ₹300 off
# 29    ₹199  ₹3451 off
# ..     ...        ...
# 70    ₹416   ₹680 off
# 71    ₹424   ₹570 off
# 72    ₹319   ₹325 off
# 73  ₹1,329  ₹2575 off
# 74    ₹674  ₹1269 off
# 75    ₹424  ₹1050 off
# 76    ₹430   ₹500 off
# 77    ₹449  ₹3075 off
# 78    ₹499   ₹685 off
# 79  ₹1,024  ₹1420 off
# 80    ₹464  ₹1528 off
# 81    ₹379  ₹2078 off
# 82    ₹470   ₹259 off
# 83  ₹3,999  ₹2124 off
# 84    ₹322   ₹552 off
# 85    ₹240   ₹219 off
# 86  ₹1,375  ₹2274 off
# 87    ₹447   ₹364 off
# 88    ₹730  ₹1003 off
# 89  ₹1,225  ₹2476 off
# 90    ₹635  ₹2200 off
# 91    ₹495  ₹1023 off
# 92    ₹424  ₹2124 off
# 93    ₹299  ₹1425 off
# 94    ₹474   ₹901 off
# 95  ₹1,375  ₹2499 off
# 96    ₹474   ₹721 off
# 97    ₹398  ₹1268 off
# 98  ₹2,500   ₹500 off
# 99    ₹278  ₹1522 off
#
# [100 rows x 4 columns]

# %% [markdown]
# # Q9."https://www.myntra.com/shoes". Set price filter "Rs 6649 to Rs 13099" and color filter to "Black" and then scrap 100 shoes data. The data should include "Brand" of shoes, shoe short-description and price. Please not: Everything should done through code even the filtering for sneakers as well.

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)
url = "https://www.myntra.com/shoes%22"
driver.get(url)
time.sleep(2)
price_button = driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")
price_button.click()
black_color_button = driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
black_color_button.click()
shoe_names=[]
s_desc=[]
short_desc=[]
price=[]
page_urls = []
time.sleep(4)
nxt_page = driver.find_elements_by_xpath("//li[@class='pagination-number']/a")
for i in nxt_page:
    page_urls.append(i.get_attribute('href'))
for url in page_urls[:3]:
    driver.get(url)
    Names=driver.find_elements_by_xpath("//div[@class='product-productMetaInfo']/h3")
    for i in Names:
        shoe_names.append(i.text)
    desc=driver.find_elements_by_xpath("//div[@class='product-productMetaInfo']/h4") 
    for i in desc:
        s_desc.append(i.text)
    for j in range(0,len(s_desc),2):
        short_desc.append(s_desc[j])
    rs=driver.find_elements_by_xpath("//div[@class='product-price']") 
    for i in rs:
        price.append(i.text)           
df=pd.DataFrame({'Brand': shoe_names[:100],'Short-description': short_desc[:100],'Price': price[:100]})
df
# Out:
#                     Brand                      Short-description  \
# 0        House of Pataudi                Men Embroidered Mojaris
# 1                    Puma           Men Flyer Beta Walking Shoes
# 2                  ADIDAS             Men Adifloss Running Shoes
# 3                 Catwalk                          Women Sandals
# 4                   Sparx                      Men Running Shoes
# 5                INVICTUS               Men Solid Formal Oxfords
# 6                     H&M                      Platform trainers
# 7                    Nike          Unisex PHANTOM Football Shoes
# 8                    Puma         Men Cell Fraction Fade Running
# 9                Roadster                 Men Mid-Top Flat Boots
# 10                   Nike            Men ZOOM FREAK 2 Basketball
# 11                   Bata              Men Solid Formal Slip-Ons
# 12               Red Tape                      Men Walking Shoes
# 13                Mactree               Men Bounce Walking Shoes
# 14                   Nike          LEBRON XVIII Basketball Shoes
# 15        PUMA Motorsport         Ferrari Race Kart Cat Sneakers
# 16                   Nike             Men AIR ZOOM Running Shoes
# 17                   Puma    Men Mesh Fuse Training Or Gym Shoes
# 18                  Levis           Men Solid Basic 2.0 Sneakers
# 19                Catwalk                          Women Sandals
# 20                   Nike              Unisex LEBRON XVIII Shoes
# 21                ZAPATOZ                    Women Walking Shoes
# 22                 Campus                      Men Running Shoes
# 23               Red Tape                Men DRIFT Walking Shoes
# 24                   Nike         Unisex LEBRON XVIII Basketball
# 25               Red Tape                      Men Walking Shoes
# 26                   Puma                     Men Football Shoes
# 27               Red Tape                      Men Walking Shoes
# 28             DressBerry                         Women Sneakers
# 29                    H&M            Solid Twisted-Strap Sandals
# ..                    ...                                    ...
# 70                   Nike              Unisex LEBRON XVIII Shoes
# 71                   Puma                    Women Walking Shoes
# 72                  Mochi                      Men Running Shoes
# 73             ELIXIR MAN                Men DRIFT Walking Shoes
# 74             Marc Loire         Unisex LEBRON XVIII Basketball
# 75             OFF LIMITS                      Men Walking Shoes
# 76         Mast & Harbour                     Men Football Shoes
# 77  HRX by Hrithik Roshan                      Men Walking Shoes
# 78                    H&M                         Women Sneakers
# 79                  ASIAN            Solid Twisted-Strap Sandals
# 80                  Mochi          Women Albertine Solid Loafers
# 81                   Nike                      Men Running Shoes
# 82                  Mochi                    Women Running Shoes
# 83                Mactree                      Men Running Shoes
# 84                    H&M              Women ZOOM SPAN 3 Running
# 85             Marc Loire                           Men Sneakers
# 86                   Bata              Women Active Running shoe
# 87             DressBerry                    Women Glitter Heels
# 88                   Puma                      Men Suede Loafers
# 89            Allen Solly              Men Flex Athleisure Shoes
# 90              J.FONTINI                   Women Open Toe Flats
# 91                  Crocs            Men SPEEDREP Training Shoes
# 92                 Reebok                      Men Running Shoes
# 93                ZAPATOZ                      Men Running Shoes
# 94                   Puma                      Men Running Shoes
# 95                    H&M                      Men Running Shoes
# 96   Kalenji By Decathlon           Men Energy 2.0 Running Shoes
# 97              mr.wonker  Men Knitted Upper Running Sport Shoes
# 98         Mast & Harbour                   Women Open Toe Flats
# 99               Skechers                Men Solid Formal Derbys
#
#                          Price
# 0    Rs. 1429Rs. 2599(45% OFF)
# 1    Rs. 2279Rs. 3799(40% OFF)
# 2    Rs. 3229Rs. 3799(15% OFF)
# 3    Rs. 1033Rs. 1695(39% OFF)
# 4     Rs. 1301Rs. 1399(7% OFF)
# 5    Rs. 1119Rs. 2799(60% OFF)
# 6                     Rs. 1999
# 7    Rs. 6396Rs. 7995(20% OFF)
# 8                     Rs. 6999
# 9     Rs. 987Rs. 2599(62% OFF)
# 10                   Rs. 10295
# 11                     Rs. 999
# 12   Rs. 2099Rs. 6999(70% OFF)
# 13    Rs. 649Rs. 2164(70% OFF)
# 14                   Rs. 17595
# 15   Rs. 4199Rs. 6999(40% OFF)
# 16   Rs. 9780Rs. 10295(5% OFF)
# 17   Rs. 6399Rs. 7999(20% OFF)
# 18   Rs. 1499Rs. 2999(50% OFF)
# 19   Rs. 1361Rs. 2095(35% OFF)
# 20                   Rs. 17595
# 21     Rs. 599Rs. 999(40% OFF)
# 22                    Rs. 1799
# 23   Rs. 1799Rs. 5999(70% OFF)
# 24                   Rs. 17595
# 25   Rs. 1469Rs. 4899(70% OFF)
# 26   Rs. 2474Rs. 4499(45% OFF)
# 27   Rs. 2189Rs. 7299(70% OFF)
# 28    Rs. 999Rs. 2499(60% OFF)
# 29                    Rs. 2299
# ..                         ...
# 70                   Rs. 17595
# 71   Rs. 2449Rs. 3499(30% OFF)
# 72   Rs. 1043Rs. 1490(30% OFF)
# 73    Rs. 519Rs. 1999(74% OFF)
# 74    Rs. 983Rs. 2399(59% OFF)
# 75   Rs. 1399Rs. 2499(44% OFF)
# 76    Rs. 999Rs. 2499(60% OFF)
# 77   Rs. 1699Rs. 3399(50% OFF)
# 78                    Rs. 2299
# 79  Rs. 464Rs. 489(Rs. 25 OFF)
# 80                    Rs. 1290
# 81  Rs. 8996Rs. 11995(25% OFF)
# 82                    Rs. 3990
# 83    Rs. 649Rs. 2164(70% OFF)
# 84                    Rs. 1299
# 85    Rs. 987Rs. 2599(62% OFF)
# 86                     Rs. 999
# 87    Rs. 874Rs. 2499(65% OFF)
# 88   Rs. 2149Rs. 4299(50% OFF)
# 89   Rs. 1367Rs. 1799(24% OFF)
# 90                    Rs. 6990
# 91                    Rs. 2495
# 92   Rs. 2419Rs. 4399(45% OFF)
# 93     Rs. 669Rs. 999(33% OFF)
# 94   Rs. 2199Rs. 3999(45% OFF)
# 95                    Rs. 1299
# 96    Rs. 1614Rs. 1699(5% OFF)
# 97    Rs. 699Rs. 3329(79% OFF)
# 98   Rs. 1249Rs. 2499(50% OFF)
# 99                    Rs. 5299
#
# [100 rows x 3 columns]

# %% [markdown]
# # Q10: Go to webpage https://www.amazon.in/Enter “Laptop” in the search field and then click the search icon.Then set CPU Type filter to “Intel Core i7” and “Intel Core i9” After setting the filters scrape first 10 laptops data.You have to scrape 3 attributes for each laptop:
# title
# Ratings
# Price

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)
url = "https://www.amazon.in/ref=nav_logo"
driver.get(url)
Title=[]
Ratings=[]
price=[]
time.sleep(2)
search_bar = driver.find_element_by_id("twotabsearchtextbox")   
search_bar.clear()                                              
search_bar.send_keys("laptops")                                   
search_button = driver.find_element_by_xpath('//span[@id="nav-search-submit-text"]')    
search_button.click()    
time.sleep(2)
filter_button=driver.find_elements_by_xpath("//a[@class='a-link-normal s-navigation-item']/span")
for i in filter_button:
    if i.text=='Intel Core i7':
        i.click()
        break          
titles=driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in titles[:10]:
    Title.append(i.text)
prices=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in prices[:10]:
    price.append(i.text)
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
UR=[]
for i in urls[:10]:
    UR.append(i.get_attribute('href'))
for url in UR:
    driver.get(url)
    try:                                                                    
        rating=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")
        Ratings.append(rating.text) 
    except NoSuchElementException:
        Ratings.append("NO rating")      
df=pd.DataFrame({'Title':Title,
                'Price':price,
                'Ratings':Ratings})
df
# Out:
#                                                Title   Price       Ratings
# 0  HP Pavilion x360 (2021) 14" (35.56cms) FHD Tou...  76,990  3.8 out of 5
# 1  (Renewed) Dell Intel Core i7 4th Gen 14 Inch(3...  45,999     NO rating
# 2  HP Pavilion (2021) Thin & Light 11th Gen Core ...  84,990  4.5 out of 5
# 3  ASUS TUF Gaming F15, 15.6" FHD 144Hz, Intel Co...  81,990  4.4 out of 5
# 4  (Renewed) HP Envy 11th Gen Core i7 Processor 1...  93,492     NO rating
# 5  HP Pavilion Gaming 10th Gen Intel Core i7 Proc...  86,990  4.1 out of 5
# 6  HP Pavilion Gaming(2021) 10th Gen Intel Core i...  90,990     NO rating
# 7  Mi Notebook Horizon Edition 14 Intel Core i7-1...  59,999  4.4 out of 5
# 8  (Renewed) Dell Intel Core i7 4th Gen 14 Inch(3...  41,999     NO rating
# 9  (Renewed) Dell Intel Core i7 4th Gen 14 Inch(3...  39,999     NO rating
