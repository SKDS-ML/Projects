# %%
#Import the Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Read the data

# %%
path = "F:/WA_Fn-UseC_-HR-Employee-Attrition.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#            ...           RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# # Finding the no of rows and columns

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# The given dataset has 1470 rows and 35 columns

# %% [markdown]
# # Finding the types of columns

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Above command shows the different types of columns in the dataset and its headers

# %% [markdown]
# # Describing the data

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Above command shows the count, mean, standard deviation, min, max and percentile of the dataset

# %%
df.describe(include= "all")
# Out:
#                 Age Attrition BusinessTravel    DailyRate  \
# count   1470.000000      1470           1470  1470.000000
# unique          NaN         2              3          NaN
# top             NaN        No  Travel_Rarely          NaN
# freq            NaN      1233           1043          NaN
# mean      36.923810       NaN            NaN   802.485714
# std        9.135373       NaN            NaN   403.509100
# min       18.000000       NaN            NaN   102.000000
# 25%       30.000000       NaN            NaN   465.000000
# 50%       36.000000       NaN            NaN   802.000000
# 75%       43.000000       NaN            NaN  1157.000000
# max       60.000000       NaN            NaN  1499.000000
#
#                     Department  DistanceFromHome    Education EducationField  \
# count                     1470       1470.000000  1470.000000           1470
# unique                       3               NaN          NaN              6
# ...

# %% [markdown]
# # Finding the information out of data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %% [markdown]
# Above command shows the information about the data including the number of non null values in the dataset which are int

# %% [markdown]
# # Finding out the datatypes

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
Above commands shows the type of dataset which are int and object type values

# %% [markdown]
# # Finding out if there are any null values

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %% [markdown]
# As per the above dataset, there are no null values present in the dataset

# %% [markdown]
# # Plotting histogram

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002463BB58438>,
# ...
#       dtype=object)

# %% [markdown]
# Above command plots the histogram of the given dataset

# %%
df.hist(figsize=(20,30))
plt.show()

# %% [markdown]
# # Identifying unique values

# %%
df['Attrition'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# Above command identifies the unique values present in the dataset for the target variable

# %% [markdown]
# # Finding out the count

# %%
df['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %% [markdown]
# Above command identifies the count present in the target variable of dataset

# %% [markdown]
# # EDA

# %% [markdown]
# # Univariate Analysis

# %%
import seaborn as sn

# %%
sn.countplot(df['Attrition']);

# %% [markdown]
# Above command plots the count of target variable of dataset. There is a class imbalance between the two variables

# %%
sn.distplot(df["DailyRate"])

# %%
Above command plots the distribution of curves of given column of dataset

# %%
sn.distplot(df["DistanceFromHome"])

# %%
sn.distplot(df["Education"])

# %%
sn.distplot(df["EmployeeCount"])

# %%
sn.distplot(df["EmployeeNumber"])

# %%
sn.distplot(df["EnvironmentSatisfaction"])

# %%
sn.distplot(df["HourlyRate"])

# %%
sn.distplot(df["JobInvolvement"])

# %%
sn.distplot(df["JobLevel"])

# %%
sn.distplot(df["JobSatisfaction"])

# %%
sn.distplot(df["MonthlyIncome"])

# %%
sn.distplot(df["MonthlyRate"])

# %%
sn.distplot(df["NumCompaniesWorked"])

# %%
sn.distplot(df["PercentSalaryHike"])

# %%
sn.distplot(df["PerformanceRating"])

# %%
sn.distplot(df["RelationshipSatisfaction"])

# %%
sn.distplot(df["StandardHours"])

# %%
sn.distplot(df["StockOptionLevel"])

# %%
sn.distplot(df["TotalWorkingYears"])

# %%
sn.distplot(df["TrainingTimesLastYear"])

# %%
sn.distplot(df["WorkLifeBalance"])

# %%
sn.distplot(df["YearsAtCompany"])

# %%
sn.distplot(df["YearsInCurrentRole"])

# %%
sn.distplot(df["YearsSinceLastPromotion"])

# %%
sn.distplot(df["YearsWithCurrManager"])

# %%
sn.distplot(df["Age"])

# %%
sn.boxplot(df["Age"])

# %% [markdown]
# The above diagram illustrates the box plot for a particular column which has no outliers

# %%
sn.boxplot(df["DailyRate"])

# %%
sn.boxplot(df["DistanceFromHome"])

# %%
sn.boxplot(df["Education"])

# %%
sn.boxplot(df["EmployeeCount"])

# %%
sn.boxplot(df["EmployeeNumber"])

# %%
sn.boxplot(df["EnvironmentSatisfaction"])

# %%
sn.boxplot(df["HourlyRate"])

# %%
sn.boxplot(df["JobInvolvement"])

# %%
sn.boxplot(df["JobLevel"])

# %%
sn.boxplot(df["JobSatisfaction"])

# %%
sn.boxplot(df["MonthlyIncome"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["MonthlyRate"])

# %%
sn.boxplot(df["NumCompaniesWorked"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["PercentSalaryHike"])

# %%
sn.boxplot(df["PerformanceRating"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["RelationshipSatisfaction"])

# %%
sn.boxplot(df["StandardHours"])

# %%
sn.boxplot(df["StockOptionLevel"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["TotalWorkingYears"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["TrainingTimesLastYear"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["WorkLifeBalance"])

# %%
sn.boxplot(df["YearsAtCompany"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["YearsInCurrentRole"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["YearsSinceLastPromotion"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
sn.boxplot(df["YearsWithCurrManager"])

# %% [markdown]
# The above diagram illustrates that there is an outlier in the given column

# %%
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=[15,3])
plt.title('Comparison between Age and HourlyRate')
sn.scatterplot(df['Age'], df['HourlyRate']);

# %% [markdown]
# Above diagram illustrates the comparision between two columnns as part of bivariate analysis

# %%
plt.figure(figsize=[15,3])
plt.title('Comparison between Age and HourlyRate')
sn.scatterplot(df['Age'], df['HourlyRate'], hue=df['Attrition']);

# %% [markdown]
# # Multivariate Analysis

# %%
cor=df.corr()

# %%
cor
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000   0.010661         -0.001686   0.208034
# DailyRate                 0.010661   1.000000         -0.004985  -0.016806
# DistanceFromHome         -0.001686  -0.004985          1.000000   0.021042
# Education                 0.208034  -0.016806          0.021042   1.000000
# EmployeeCount                  NaN        NaN               NaN        NaN
# EmployeeNumber           -0.010145  -0.050990          0.032916   0.042070
# EnvironmentSatisfaction   0.010146   0.018355         -0.016075  -0.027128
# HourlyRate                0.024287   0.023381          0.031131   0.016775
# JobInvolvement            0.029820   0.046135          0.008783   0.042438
# JobLevel                  0.509604   0.002966          0.005303   0.101589
# JobSatisfaction          -0.004892   0.030571         -0.003669  -0.011296
# ...

# %% [markdown]
# Above command shows the corelation between Variables for the given dataset

# %%
sn.heatmap(cor,annot=True,linewidths=1,linecolor ='green')

# %% [markdown]
# Above diagram illustrates the heatmap for the given dataset

# %% [markdown]
# # Encoding

# %%
Ordinal Encoding to convert Categorical Values to Numerical Values

# %%
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
for i in df.columns:
    if df[i].dtypes=="object":
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41        1.0             2.0       1102         2.0                 1
# 1      49        0.0             1.0        279         1.0                 8
# 2      37        1.0             2.0       1373         1.0                 2
# 3      33        0.0             1.0       1392         1.0                 3
# 4      27        0.0             2.0        591         1.0                 2
# 5      32        0.0             1.0       1005         1.0                 2
# 6      59        0.0             2.0       1324         1.0                 3
# 7      30        0.0             2.0       1358         1.0                24
# 8      38        0.0             1.0        216         1.0                23
# 9      36        0.0             2.0       1299         1.0                27
# 10     35        0.0             2.0        809         1.0                16
# ...

# %% [markdown]
# # Removing Outliers using Zscore

# %%
from scipy.stats import zscore

z=np.abs(zscore(df))

new_df=df[(z<3)]

# %% [markdown]
# Above command is to remove outliers using Zscore technique for the given dataset

# %% [markdown]
# # Finding out New Shape

# %%
new_df.shape
# Out:
# (46930, 35)

# %% [markdown]
# Finding out new shape or count of columns after removing outliers

# %% [markdown]
# # Finding out Skewness

# %%
new_df.skew()
# Out:
# Age                         0.415182
# Attrition                   1.841314
# BusinessTravel             -1.437089
# DailyRate                  -0.004190
# Department                  0.172091
# DistanceFromHome            0.957269
# Education                  -0.289205
# EducationField              0.549630
# EmployeeCount               0.000000
# EmployeeNumber              0.016447
# EnvironmentSatisfaction    -0.321259
# Gender                     -0.408080
# HourlyRate                 -0.032330
# JobInvolvement             -0.497994
# JobLevel                    1.028839
# JobRole                    -0.358029
# JobSatisfaction            -0.329921
# MaritalStatus              -0.152163
# MonthlyIncome               1.375675
# MonthlyRate                 0.019033
# NumCompaniesWorked          1.025940
# Over18                      0.000000
# OverTime                    0.963404
# PercentSalaryHike           0.819337
# PerformanceRating           1.920230
# ...

# %% [markdown]
# Finding out skewness after removing outliers

# %%
x=new_df.drop("Attrition",axis=1)
y=new_df["Attrition"]

# %% [markdown]
# # Importing  train_test_split

# %%
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score

# %% [markdown]
# # Identifying Best Random State

# %%
for i in range(5):
    x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.33, random_state=i)
    from sklearn.tree import DecisionTreeClassifier
    lm=DecisionTreeClassifier()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    accu=accuracy_score(y_test,pred)
    print(accu*100, "at random_state", i)
# Out:
# 100.0 at random_state 0
# 100.0 at random_state 1
# 100.0 at random_state 2
# 100.0 at random_state 3
# 100.0 at random_state 4

# %%
from sklearn.tree import DecisionTreeClassifier
maxAccu=0
maxRS=0
for i in range(1,5):
    x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.30, random_state=i)
    mod = DecisionTreeClassifier()
    mod.fit(x_train, y_train)
    pred=mod.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAccu:
        maxAccu=accu
        maxRS=i
    print("Best accuracy is ",maxAccu," on Random_state ", maxRS)
# Out:
# Best accuracy is  1.0  on Random_state  1
# Best accuracy is  1.0  on Random_state  1
# Best accuracy is  1.0  on Random_state  1
# Best accuracy is  1.0  on Random_state  1

# %%
x_train, x_test, y_train, y_test = train_test_split (x,y,test_size=0.30, random_state=1)

# %% [markdown]
# # Problem Identification: Since we have to predict the Attrition from the given dataset, this is a supervised algorithm. The target variable is Attrition column. Since the values are categorical or Y/N, we are applying classification algorithm

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score, classification_report,confusion_matrix

# %% [markdown]
# # Fitting DTC Algorithm

# %%
DTC = DecisionTreeClassifier()
DTC.fit(x_train, y_train)
pred = DTC.predict(x_test)
print("accuracy train:",DTC.score(x_train,y_train),"\n")
print("accuracy test:",DTC.score(x_test,y_test),"\n")
print("precision :",precision_score(y_test,pred),"\n")
print("Recall :",recall_score(y_test,pred),"\n")
print("f1 score:",f1_score(y_test,pred),"\n")
print("Confusion Matrix \n",confusion_matrix(y_test,pred))
acc=classification_report(y_test,pred)
print(acc)
# Out:
# accuracy train: 1.0
#
# accuracy test: 1.0
#
# precision : 1.0
#
# Recall : 1.0
#
# f1 score: 1.0
#
# Confusion Matrix
#  [[11831     0]
#  [    0  2248]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     11831
#          1.0       1.00      1.00      1.00      2248
#
#    micro avg       1.00      1.00      1.00     14079
#    macro avg       1.00      1.00      1.00     14079
# weighted avg       1.00      1.00      1.00     14079

# %% [markdown]
# # Fitting RFC Algorithm

# %%
RFC = RandomForestClassifier()
RFC.fit(x_train, y_train)
pred = RFC.predict(x_test)
print("accuracy train:",RFC.score(x_train,y_train),"\n")
print("accuracy test:",RFC.score(x_test,y_test),"\n")
print("precision :",precision_score(y_test,pred),"\n")
print("Recall :",recall_score(y_test,pred),"\n")
print("f1 score:",f1_score(y_test,pred),"\n")
print("Confusion Matrix \n",confusion_matrix(y_test,pred))
acc=classification_report(y_test,pred)
print(acc)
# Out:
# accuracy train: 1.0
#
# accuracy test: 1.0
#
# precision : 1.0
#
# Recall : 1.0
#
# f1 score: 1.0
#
# Confusion Matrix
#  [[11831     0]
#  [    0  2248]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     11831
#          1.0       1.00      1.00      1.00      2248
#
#    micro avg       1.00      1.00      1.00     14079
#    macro avg       1.00      1.00      1.00     14079
# weighted avg       1.00      1.00      1.00     14079

# %%
from sklearn import svm

# %% [markdown]
# # Fitting SVC Algorithm

# %%
SVC = svm.SVC()
SVC.fit(x_train, y_train)
pred = SVC.predict(x_test)
print("accuracy train:",RFC.score(x_train,y_train),"\n")
print("accuracy test:",RFC.score(x_test,y_test),"\n")
print("precision :",precision_score(y_test,pred),"\n")
print("Recall :",recall_score(y_test,pred),"\n")
print("f1 score:",f1_score(y_test,pred),"\n")
print("Confusion Matrix \n",confusion_matrix(y_test,pred))
acc=classification_report(y_test,pred)
print(acc)
# Out:
# accuracy train: 1.0
#
# accuracy test: 1.0
#
# precision : 1.0
#
# Recall : 1.0
#
# f1 score: 1.0
#
# Confusion Matrix
#  [[11831     0]
#  [    0  2248]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     11831
#          1.0       1.00      1.00      1.00      2248
#
#    micro avg       1.00      1.00      1.00     14079
#    macro avg       1.00      1.00      1.00     14079
# weighted avg       1.00      1.00      1.00     14079

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Cross Validation

# %%
print(cross_val_score(DTC,x,y,cv=4).mean())
# Out:
# 0.7781378203236583

# %%
print(cross_val_score(RFC,x,y,cv=4).mean())
# Out:
# 0.850244869371473

# %%
print(cross_val_score(SVC,x,y,cv=4).mean())
# Out:
# 0.8406989111695912

# %% [markdown]
# Cross Validation to improve the model accuracy

# %%
from sklearn.model_selection import GridSearchCV
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
parameter = {'max_depth' : np.arange(2,10),
             'criterion':['gini', 'entropy']}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameter,cv=4)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=4, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'max_depth': array([2, 3, 4, 5, 6, 7, 8, 9]), 'criterion': ['gini', 'entropy']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
GCV.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 9}

# %% [markdown]
# # Final Model

# %%
Final_mod = RandomForestClassifier(criterion='entropy',max_depth=9)
Final_mod.fit(x_train,y_train)
pred = Final_mod.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 96.51963917891896
